# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(data);

# %%
fig = plt.figure(figsize = (4.5,3)) # ancho 4.5, alto 3
ax = plt.axes()
ax.hist(data);

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(data,
        bins = 50, #nº de barras
        alpha = 0.7, #grado de transparencia
        color = 'steelblue'
        );

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha = 0.3, bins = 20)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.Figure()
ax = plt.axes()
limites = ax.hist(x1, alpha = 0.3, bins = 30)

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites[0]
# Out:
# array([  2.,   3.,   4.,   4.,  11.,   7.,  19.,  21.,  37.,  38.,  53.,
#         75.,  78.,  73., 101.,  75.,  66.,  81.,  65.,  52.,  48.,  32.,
#         24.,   8.,   8.,   9.,   2.,   2.,   1.,   1.])

# %%
limites[1]
# Out:
# array([-2.46336037, -2.29706477, -2.13076916, -1.96447355, -1.79817795,
#        -1.63188234, -1.46558673, -1.29929112, -1.13299552, -0.96669991,
#        -0.8004043 , -0.6341087 , -0.46781309, -0.30151748, -0.13522188,
#         0.03107373,  0.19736934,  0.36366494,  0.52996055,  0.69625616,
#         0.86255176,  1.02884737,  1.19514298,  1.36143859,  1.52773419,
#         1.6940298 ,  1.86032541,  2.02662101,  2.19291662,  2.35921223,
#         2.52550783])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt.boxplot(data, whis = 1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcaa00ae190>,
#   <matplotlib.lines.Line2D at 0x7fcaa00ae640>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fcaa00ae9d0>,
#   <matplotlib.lines.Line2D at 0x7fcaa00ae0a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcaa00aeee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca9fd07b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca9fd07dc0>],
#  'means': []}

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(data, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fca9ff095e0>,
#   <matplotlib.lines.Line2D at 0x7fca9ff098b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fca9ff09b50>,
#   <matplotlib.lines.Line2D at 0x7fca9ff09df0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fca9ff09340>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca9ff390d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca9ff39370>],
#  'means': []}

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt.boxplot([x1, x2, x3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fca9fc88df0>,
#   <matplotlib.lines.Line2D at 0x7fca9fc9b0d0>,
#   <matplotlib.lines.Line2D at 0x7fca9fca8100>,
#   <matplotlib.lines.Line2D at 0x7fca9fca83a0>,
#   <matplotlib.lines.Line2D at 0x7fca9fcb93a0>,
#   <matplotlib.lines.Line2D at 0x7fca9fcb9640>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fca9fc9b3a0>,
#   <matplotlib.lines.Line2D at 0x7fca9fc9b640>,
#   <matplotlib.lines.Line2D at 0x7fca9fca8640>,
#   <matplotlib.lines.Line2D at 0x7fca9fca88e0>,
#   <matplotlib.lines.Line2D at 0x7fca9fcb98e0>,
#   <matplotlib.lines.Line2D at 0x7fca9fcb9b80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fca9fc88be0>,
#   <matplotlib.lines.Line2D at 0x7fca9fc9be20>,
#   <matplotlib.lines.Line2D at 0x7fca9fcb9100>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fca9fc9b8e0>,
#   <matplotlib.lines.Line2D at 0x7fca9fca8b80>,
#   <matplotlib.lines.Line2D at 0x7fca9fcb9e20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fca9fc9bb80>,
#   <matplotlib.lines.Line2D at 0x7fca9fca8e20>,
#   <matplotlib.lines.Line2D at 0x7fca9fc47100>],
#  'means': []}
